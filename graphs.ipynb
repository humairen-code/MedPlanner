# %% [markdown]
# This is our Jupyter Notebook for making our graphs.

# %%
import pandas as pd
df = pd.read_csv("incidents.datas.csv")
df = df.dropna(how = "all", axis =1)
df = df.drop(df.columns[0:2], axis=1)
print(df.head())
# Out:
#   Incident Date  Time                                       Location  \
# 0    2025-02-25    19                         Air/Bus/Train Terminal
# 1    2026-07-12    12                         Air/Bus/Train Terminal
# 2    2026-08-13    11                         Air/Bus/Train Terminal
# 3    2026-08-21    14                         Air/Bus/Train Terminal
# 4    2026-06-04    19  Jail/Prison/Penitentiary/Corrections Facility
#
#                                         Offense  \
# 0                        13A-Aggravated Assault
# 1  290-Destruction/Damage/Vandalism of Property
# 2  290-Destruction/Damage/Vandalism of Property
# 3                              13C-Intimidation
# 4                            13B-Simple Assault
#
#                     Bias Motivation  Victim Sex, Age and Race  \
# 0  12-Anti-Black or African American            1. F - 23 - P
# 1             25-Anti-Other Religion            1. Government
# 2             25-Anti-Other Religion              1. Business
# ...
